# %%
5. Implement the Continuous Bag of Words (CBOW) Model. Stages can be:
a. Data preparation
b. Generate training data
c. Train model
d. Output

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,\
	Embedding, Lambda
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import re

# %%
data = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells."""

# %%
# for importing data from txt file
# with open("data.txt", "r", encoding="utf-8") as file:
#     data = file.read()

# %%
sentences = data.split(".")

# %%
sentences
# Out:
# ['We are about to study the idea of a computational process',
#  '\nComputational processes are abstract beings that inhabit computers',
#  '\nAs they evolve, processes manipulate other abstract things called data',
#  '\nThe evolution of a process is directed by a pattern of rules\ncalled a program',
#  ' People create programs to direct processes',
#  ' In effect,\nwe conjure the spirits of the computer with our spells',
#  '']

# %%
#Clean Data
clean_sentences = []
for sentence in sentences:
    # skip empty string
    if sentence == "":
        continue;
    # remove special characters
    sentence = re.sub('[^A-Za-z0-9]+', ' ', sentence)
    # remove 1 letter words
    sentence = re.sub(r'(?:^| )\w(?:$| )', ' ', sentence).strip()
    # lower all characters
    sentence = sentence.lower()
    clean_sentences.append(sentence)

# %%
clean_sentences
# Out:
# ['we are about to study the idea of computational process',
#  'computational processes are abstract beings that inhabit computers',
#  'as they evolve processes manipulate other abstract things called data',
#  'the evolution of process is directed by pattern of rules called program',
#  'people create programs to direct processes',
#  'in effect we conjure the spirits of the computer with our spells']

# %%
# Define the corpus
corpus = clean_sentences

# %%
# Convert the corpus to a sequence of integers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
print("After converting our words in the corpus \
into vector of integers:")
print(sequences)
# Out:
# After converting our words in the corpus into vector of integers:
# [[4, 5, 11, 6, 12, 1, 13, 2, 7, 8], [7, 3, 5, 9, 14, 15, 16, 17], [18, 19, 20, 3, 21, 22, 9, 23, 10, 24], [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31], [32, 33, 34, 6, 35, 3], [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]]

# %%
# creating dictionary for word to index and index to word
index_to_word_map = {}
word_to_index_map = {}
for index_1, sequence in enumerate(sequences):
    print(sequence)
    words_in_sentence = clean_sentences[index_1].split()
    print(words_in_sentence)
    for index_2, value in enumerate(sequence):
        index_to_word_map[value] = words_in_sentence[index_2]
        word_to_index_map[words_in_sentence[index_2]] = value
# Out:
# [4, 5, 11, 6, 12, 1, 13, 2, 7, 8]
# ['we', 'are', 'about', 'to', 'study', 'the', 'idea', 'of', 'computational', 'process']
# [7, 3, 5, 9, 14, 15, 16, 17]
# ['computational', 'processes', 'are', 'abstract', 'beings', 'that', 'inhabit', 'computers']
# [18, 19, 20, 3, 21, 22, 9, 23, 10, 24]
# ['as', 'they', 'evolve', 'processes', 'manipulate', 'other', 'abstract', 'things', 'called', 'data']
# [1, 25, 2, 8, 26, 27, 28, 29, 2, 30, 10, 31]
# ['the', 'evolution', 'of', 'process', 'is', 'directed', 'by', 'pattern', 'of', 'rules', 'called', 'program']
# [32, 33, 34, 6, 35, 3]
# ['people', 'create', 'programs', 'to', 'direct', 'processes']
# [36, 37, 4, 38, 1, 39, 2, 1, 40, 41, 42, 43]
# ['in', 'effect', 'we', 'conjure', 'the', 'spirits', 'of', 'the', 'computer', 'with', 'our', 'spells']

# %%
print(index_to_word_map)
print("\n")
print(word_to_index_map)
# Out:
# {4: 'we', 5: 'are', 11: 'about', 6: 'to', 12: 'study', 1: 'the', 13: 'idea', 2: 'of', 7: 'computational', 8: 'process', 3: 'processes', 9: 'abstract', 14: 'beings', 15: 'that', 16: 'inhabit', 17: 'computers', 18: 'as', 19: 'they', 20: 'evolve', 21: 'manipulate', 22: 'other', 23: 'things', 10: 'called', 24: 'data', 25: 'evolution', 26: 'is', 27: 'directed', 28: 'by', 29: 'pattern', 30: 'rules', 31: 'program', 32: 'people', 33: 'create', 34: 'programs', 35: 'direct', 36: 'in', 37: 'effect', 38: 'conjure', 39: 'spirits', 40: 'computer', 41: 'with', 42: 'our', 43: 'spells'}
#
#
# {'we': 4, 'are': 5, 'about': 11, 'to': 6, 'study': 12, 'the': 1, 'idea': 13, 'of': 2, 'computational': 7, 'process': 8, 'processes': 3, 'abstract': 9, 'beings': 14, 'that': 15, 'inhabit': 16, 'computers': 17, 'as': 18, 'they': 19, 'evolve': 20, 'manipulate': 21, 'other': 22, 'things': 23, 'called': 10, 'data': 24, 'evolution': 25, 'is': 26, 'directed': 27, 'by': 28, 'pattern': 29, 'rules': 30, 'program': 31, 'people': 32, 'create': 33, 'programs': 34, 'direct': 35, 'in': 36, 'effect': 37, 'conjure': 38, 'spirits': 39, 'computer': 40, 'with': 41, 'our': 42, 'spells': 43}

# %%
# Define the parameters
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 10
window_size = 2

# Generate the context-target pairs
contexts = []
targets = []
for sequence in sequences:
	for i in range(window_size, len(sequence) - window_size):
		context = sequence[i - window_size:i] + sequence[i + 1:i + window_size + 1]
		target = sequence[i]
		contexts.append(context)
		targets.append(target)

# %%
# sample of training data
for i in range(5):
    words = []
    target = index_to_word_map.get(targets[i])
    for j in contexts[i]:
        words.append(index_to_word_map.get(j))
    print(words, "=>", target)
# Out:
# ['we', 'are', 'to', 'study'] => about
# ['are', 'about', 'study', 'the'] => to
# ['about', 'to', 'the', 'idea'] => study
# ['to', 'study', 'idea', 'of'] => the
# ['study', 'the', 'of', 'computational'] => idea

# %%
# Convert the contexts and targets to numpy arrays
X = np.array(contexts)
Y = np.array(targets)

# %%
# Define the CBOW model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2 * window_size))
model.add(Lambda(lambda x: tf.reduce_mean(x, axis=1)))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(units=vocab_size, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, Y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# C:\Users\ashut\anaconda3\envs\deep_learn\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\ashut\anaconda3\envs\deep_learn\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.0588 - loss: 3.7836
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1176 - loss: 3.7749
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1176 - loss: 3.7674
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1176 - loss: 3.7596
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1176 - loss: 3.7495
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1176 - loss: 3.7386
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1176 - loss: 3.7255
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1176 - loss: 3.7105
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1176 - loss: 3.6926
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1176 - loss: 3.6720
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1176 - loss: 3.6465
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1176 - loss: 3.6187
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1176 - loss: 3.5867
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1176 - loss: 3.5512
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1176 - loss: 3.5126
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1176 - loss: 3.4710
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1176 - loss: 3.4226
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1765 - loss: 3.3758
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.1765 - loss: 3.3281
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1765 - loss: 3.2759
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1765 - loss: 3.2259
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1765 - loss: 3.1769
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1765 - loss: 3.1315
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1765 - loss: 3.0914
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1765 - loss: 3.0537
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2647 - loss: 3.0183
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2941 - loss: 2.9867
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2941 - loss: 2.9514
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3235 - loss: 2.9205
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3235 - loss: 2.8857
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3235 - loss: 2.8502
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3235 - loss: 2.8104
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2941 - loss: 2.7772
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2941 - loss: 2.7427
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3235 - loss: 2.7067
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3235 - loss: 2.6759
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2941 - loss: 2.6418
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2941 - loss: 2.6080
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2647 - loss: 2.5679
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2647 - loss: 2.5325
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2941 - loss: 2.5000
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2941 - loss: 2.4651
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2941 - loss: 2.4317
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2941 - loss: 2.3958
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2941 - loss: 2.3583
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2941 - loss: 2.3158
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2941 - loss: 2.2758
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2941 - loss: 2.2380
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2941 - loss: 2.2069
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2941 - loss: 2.1783
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2941 - loss: 2.1515
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3529 - loss: 2.1133
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3824 - loss: 2.0742
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4118 - loss: 2.0384
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4118 - loss: 2.0120
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3824 - loss: 1.9824
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3529 - loss: 1.9518
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3529 - loss: 1.9178
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3824 - loss: 1.8885
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4412 - loss: 1.8497
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4412 - loss: 1.8172
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4412 - loss: 1.7843
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4412 - loss: 1.7560
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5000 - loss: 1.7245
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5000 - loss: 1.6928
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 1.6692
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4706 - loss: 1.6455
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4706 - loss: 1.6261
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4706 - loss: 1.6063
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4706 - loss: 1.5798
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4706 - loss: 1.5545
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4706 - loss: 1.5234
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4706 - loss: 1.4923
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5000 - loss: 1.4670
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5000 - loss: 1.4481
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5882 - loss: 1.4317
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5588 - loss: 1.4143
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5588 - loss: 1.3922
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5588 - loss: 1.3731
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5588 - loss: 1.3387
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5588 - loss: 1.3070
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5882 - loss: 1.2862
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6176 - loss: 1.2537
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5588 - loss: 1.2179
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5882 - loss: 1.1800
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6176 - loss: 1.1449
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5882 - loss: 1.1266
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5882 - loss: 1.1173
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5588 - loss: 1.1150
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5882 - loss: 1.1015
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6176 - loss: 1.0917
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6176 - loss: 1.0726
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6176 - loss: 1.0292
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6176 - loss: 0.9830
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6471 - loss: 0.9457
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7353 - loss: 0.9208
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7941 - loss: 0.9048
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7647 - loss: 0.8955
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7647 - loss: 0.8782
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7647 - loss: 0.8482
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8529 - loss: 0.8117
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8529 - loss: 0.7884
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8529 - loss: 0.7672
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8529 - loss: 0.7513
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8824 - loss: 0.7344
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8824 - loss: 0.7138
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9412 - loss: 0.6927
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9706 - loss: 0.6578
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.6279
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9706 - loss: 0.6051
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9412 - loss: 0.5984
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9118 - loss: 0.5840
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9118 - loss: 0.5712
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8824 - loss: 0.5586
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8529 - loss: 0.5516
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8529 - loss: 0.5439
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8529 - loss: 0.5338
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8824 - loss: 0.5166
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8529 - loss: 0.5091
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8529 - loss: 0.4962
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8824 - loss: 0.4770
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8824 - loss: 0.4648
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9118 - loss: 0.4596
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8529 - loss: 0.4639
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8235 - loss: 0.4722
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7941 - loss: 0.4717
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8235 - loss: 0.4439
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9118 - loss: 0.4083
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9412 - loss: 0.3902
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9118 - loss: 0.3829
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9118 - loss: 0.3794
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9118 - loss: 0.3758
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9118 - loss: 0.3674
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9118 - loss: 0.3584
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9412 - loss: 0.3450
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9412 - loss: 0.3303
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9412 - loss: 0.3158
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9412 - loss: 0.3047
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9412 - loss: 0.2976
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9412 - loss: 0.2925
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.2869
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.2777
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.2654
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.2550
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.2465
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.2420
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9706 - loss: 0.2389
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9706 - loss: 0.2355
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.2325
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.2295
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.2235
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.2177
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.2075
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1969
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1933
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.1919
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.1905
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1876
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1823
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1765
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.1778
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.1811
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9706 - loss: 0.1815
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.1770
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9706 - loss: 0.1694
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9706 - loss: 0.1600
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9706 - loss: 0.1509
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9706 - loss: 0.1439
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9706 - loss: 0.1377
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9706 - loss: 0.1327
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1283
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.1252
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.1221
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.1186
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.1172
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1245
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9706 - loss: 0.1271
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1119
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.1019
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1054
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.1136
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1246
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1337
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9706 - loss: 0.1380
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9706 - loss: 0.1360
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9706 - loss: 0.1292
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9706 - loss: 0.1219
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.1140
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9706 - loss: 0.1058
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9706 - loss: 0.0979
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9706 - loss: 0.0907
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9706 - loss: 0.0847
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0796
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0754
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0727
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0713
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0688
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0690
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0667
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0634

# %%
# Get the word embeddings
embeddings = model.get_weights()[0]

# Perform PCA to reduce the dimensionality of the embeddings
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(embeddings)

# %%
# Visualize the embeddings
plt.figure(figsize=(7, 7))
for i, word in enumerate(tokenizer.word_index.keys()):
    x, y = reduced_embeddings[i]
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2),
                 textcoords='offset points',
                 ha='right', va='bottom')
plt.show()

# %%
# test model
test_sentenses = [
    "we are to study",
    "create programs direct processes",
    "spirits process study program",
    "idea study people create"
]

# %%
for test_sentense in test_sentenses:
    test_words = test_sentense.split(" ")
    print("Words: ", test_words)
    x_test = []
    for i in test_words:
        x_test.append(word_to_index_map.get(i))
    x_test = np.array([x_test])
    print("Indexs: ", x_test)
    test_predictions = model.predict(x_test)
    y_pred = np.argmax(test_predictions[0])
    print("Predictons: ",test_words, " => ", index_to_word_map.get(y_pred))
    print("\n")
# Out:
# Words:  ['we', 'are', 'to', 'study']
# Indexs:  [[ 4  5  6 12]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Predictons:  ['we', 'are', 'to', 'study']  =>  about
#
#
# Words:  ['create', 'programs', 'direct', 'processes']
# Indexs:  [[33 34 35  3]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predictons:  ['create', 'programs', 'direct', 'processes']  =>  to
#
#
# Words:  ['spirits', 'process', 'study', 'program']
# Indexs:  [[39  8 12 31]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predictons:  ['spirits', 'process', 'study', 'program']  =>  rules
#
#
# Words:  ['idea', 'study', 'people', 'create']
# Indexs:  [[13 12 32 33]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predictons:  ['idea', 'study', 'people', 'create']  =>  to
